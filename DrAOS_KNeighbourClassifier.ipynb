# %%
#gather Data
from sklearn.datasets import fetch_mldata

mnist = fetch_mldata('MNIST original')

# split the data into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(mnist["data"], mnist["target"], test_size=0.1, random_state=0)

# %%
! [ ! -z "$COLAB_GPU" ] && pip install torch scikit-learn==0.20.* skorch
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python2.7/dist-packages (1.4.0)
# Requirement already satisfied: scikit-learn==0.20.* in /usr/local/lib/python2.7/dist-packages (0.20.3)
# Collecting skorch
#   Downloading https://files.pythonhosted.org/packages/ff/5c/8c39bdff43f2b2ed452a1d7e5e3a92ba0452a76db57a388097cd715e6846/skorch-0.8.0.tar.gz (101kB)
#      |████████████████████████████████| 102kB 3.6MB/s
# Requirement already satisfied: scipy>=0.13.3 in /usr/local/lib/python2.7/dist-packages (from scikit-learn==0.20.*) (1.2.2)
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python2.7/dist-packages (from scikit-learn==0.20.*) (1.16.4)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python2.7/dist-packages (from skorch) (0.8.3)
# Requirement already satisfied: tqdm>=4.14.0 in /usr/local/lib/python2.7/dist-packages (from skorch) (4.28.1)
# Building wheels for collected packages: skorch
#   Building wheel for skorch (setup.py) ... done
#   Created wheel for skorch: filename=skorch-0.8.0-cp27-none-any.whl size=113709 sha256=98a918c6a324fe5a159b646c71d8cf52322540691b54d9f83a73d6d9d34319f1
#   Stored in directory: /root/.cache/pip/wheels/e3/eb/f8/bbd8c3fd9ef12f6220efa9856472fcc0749a3e42bb10d40fba
# Successfully built skorch
# Installing collected packages: skorch
# Successfully installed skorch-0.8.0

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
mnist = fetch_openml('mnist_784', cache=False)
X_train, X_test, y_train, y_test = train_test_split(mnist["data"], mnist["target"], test_size=0.1, random_state=0)

# %%
# prepare the data

from sklearn.neighbors import KNeighborsClassifier

knn_clf = KNeighborsClassifier()
knn_clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
pos = 11
print(knn_clf.predict([X_test[pos]]))
print(y_test[pos])
# Out:
# ['3']
# 3

# %%
knn_clf.score(X_test, y_test)
# Out:
# 0.9758571428571429

# %%
graph = knn_clf.kneighbors_graph(X_test, n_neighbors=3, mode="connectivity")
graph.toarray()

# %%
graph_arr = graph.toarray()
